# %% [markdown]
# # Purpose
#
# e-Stat API wrapper を試す。

# %%
import os
from estat_api.api import EstatAPI
from estat_api.parameters import CommonParameters

# %%
api: EstatAPI = EstatAPI(os.environ.get('ESTAT_APP_ID'))

# %% [markdown]
# # get statistical table information

# %%
params: dict = {
    "surveyYear": "2025",
    "stateField": "01",
    "searchWord": ""
}

response = api.get_stats_list(**params)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File c:\Users\thiraki\anaconda3\envs\estat_dev\Lib\http\client.py:1411, in HTTPConnection.getresponse(self)
#    1410 try:
# -> 1411     response.begin()
#    1412 except ConnectionError:
#
# File c:\Users\thiraki\anaconda3\envs\estat_dev\Lib\http\client.py:324, in HTTPResponse.begin(self)
#     323 while True:
# --> 324     version, status, reason = self._read_status()
#     325     if status != CONTINUE:
#
# File c:\Users\thiraki\anaconda3\envs\estat_dev\Lib\http\client.py:285, in HTTPResponse._read_status(self)
#     284 def _read_status(self):
# --> 285     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     286     if len(line) > _MAXLINE:
#
# File c:\Users\thiraki\anaconda3\envs\estat_dev\Lib\socket.py:707, in SocketIO.readinto(self, b)
#     706 try:
# --> 707     return self._sock.recv_into(b)
# ...
